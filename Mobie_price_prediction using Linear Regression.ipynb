# %%
import pandas as pd

# %%
import numpy as np
import pickle

# %%
data =pd. read_csv("Cellphone.csv")

# %%
data
# Out:
#      Product_id  Price  Sale  weight  resoloution  ppi  cpu core  cpu freq  \
# 0           203   2357    10   135.0         5.20  424         8     1.350
# 1           880   1749    10   125.0         4.00  233         2     1.300
# 2            40   1916    10   110.0         4.70  312         4     1.200
# 3            99   1315    11   118.5         4.00  233         2     1.300
# 4           880   1749    11   125.0         4.00  233         2     1.300
# ..          ...    ...   ...     ...          ...  ...       ...       ...
# 156        1206   3551  4638   178.0         5.46  538         4     1.875
# 157        1296   3211  8016   170.0         5.50  534         4     1.975
# 158         856   3260  8809   150.0         5.50  401         8     2.200
# 159        1296   3211  8946   170.0         5.50  534         4     1.975
# 160        1131   2536  9807   202.0         6.00  367         8     1.500
#
#      internal mem    ram  RearCam  Front_Cam  battery  thickness
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 161 entries, 0 to 160
# Data columns (total 14 columns):
#  #   Column        Non-Null Count  Dtype
# ---  ------        --------------  -----
#  0   Product_id    161 non-null    int64
#  1   Price         161 non-null    int64
#  2   Sale          161 non-null    int64
#  3   weight        161 non-null    float64
#  4   resoloution   161 non-null    float64
#  5   ppi           161 non-null    int64
#  6   cpu core      161 non-null    int64
#  7   cpu freq      161 non-null    float64
#  8   internal mem  161 non-null    float64
#  9   ram           161 non-null    float64
#  10  RearCam       161 non-null    float64
#  11  Front_Cam     161 non-null    float64
#  12  battery       161 non-null    int64
#  13  thickness     161 non-null    float64
# dtypes: float64(8), int64(6)
# memory usage: 17.7 KB

# %%
data.describe()
# Out:
#         Product_id        Price         Sale      weight  resoloution  \
# count   161.000000   161.000000   161.000000  161.000000   161.000000
# mean    675.559006  2215.596273   621.465839  170.426087     5.209938
# std     410.851583   768.187171  1546.618517   92.888612     1.509953
# min      10.000000   614.000000    10.000000   66.000000     1.400000
# 25%     237.000000  1734.000000    37.000000  134.100000     4.800000
# 50%     774.000000  2258.000000   106.000000  153.000000     5.150000
# 75%    1026.000000  2744.000000   382.000000  170.000000     5.500000
# max    1339.000000  4361.000000  9807.000000  753.000000    12.200000
#
#               ppi    cpu core    cpu freq  internal mem         ram  \
# count  161.000000  161.000000  161.000000    161.000000  161.000000
# mean   335.055901    4.857143    1.502832     24.501714    2.204994
# std    134.826659    2.444016    0.599783     28.804773    1.609831
# ...

# %%
data.shape
# Out:
# (161, 14)

# %%
data.isnull().count()
# Out:
# Product_id      161
# Price           161
# Sale            161
# weight          161
# resoloution     161
# ppi             161
# cpu core        161
# cpu freq        161
# internal mem    161
# ram             161
# RearCam         161
# Front_Cam       161
# battery         161
# thickness       161
# dtype: int64

# %%
data1=data.drop(["Product_id","ppi","cpu core","cpu freq"],axis=1)

# %%
data1
# Out:
#      Price  Sale  weight  resoloution  internal mem    ram  RearCam  \
# 0     2357    10   135.0         5.20          16.0  3.000    13.00
# 1     1749    10   125.0         4.00           4.0  1.000     3.15
# 2     1916    10   110.0         4.70           8.0  1.500    13.00
# 3     1315    11   118.5         4.00           4.0  0.512     3.15
# 4     1749    11   125.0         4.00           4.0  1.000     3.15
# ..     ...   ...     ...          ...           ...    ...      ...
# 156   3551  4638   178.0         5.46         128.0  6.000    12.00
# 157   3211  8016   170.0         5.50         128.0  6.000    20.00
# 158   3260  8809   150.0         5.50          64.0  4.000    20.00
# 159   3211  8946   170.0         5.50         128.0  6.000    20.00
# 160   2536  9807   202.0         6.00          16.0  3.000    21.50
#
#      Front_Cam  battery  thickness
# 0          8.0     2610        7.4
# 1          0.0     1700        9.9
# 2          5.0     2000        7.6
# ...

# %%
data1.columns
# Out:
# Index(['Price', 'Sale', 'weight', 'resoloution', 'internal mem', 'ram',
#        'RearCam', 'Front_Cam', 'battery', 'thickness'],
#       dtype='object')

# %%
y = data1['Price']

# %%
y
# Out:
# 0      2357
# 1      1749
# 2      1916
# 3      1315
# 4      1749
#        ...
# 156    3551
# 157    3211
# 158    3260
# 159    3211
# 160    2536
# Name: Price, Length: 161, dtype: int64

# %%
x=data1.drop(['Price'],axis=1)

# %%
x
# Out:
#      Sale  weight  resoloution  internal mem    ram  RearCam  Front_Cam  \
# 0      10   135.0         5.20          16.0  3.000    13.00        8.0
# 1      10   125.0         4.00           4.0  1.000     3.15        0.0
# 2      10   110.0         4.70           8.0  1.500    13.00        5.0
# 3      11   118.5         4.00           4.0  0.512     3.15        0.0
# 4      11   125.0         4.00           4.0  1.000     3.15        0.0
# ..    ...     ...          ...           ...    ...      ...        ...
# 156  4638   178.0         5.46         128.0  6.000    12.00       16.0
# 157  8016   170.0         5.50         128.0  6.000    20.00        8.0
# 158  8809   150.0         5.50          64.0  4.000    20.00       20.0
# 159  8946   170.0         5.50         128.0  6.000    20.00        8.0
# 160  9807   202.0         6.00          16.0  3.000    21.50       16.0
#
#      battery  thickness
# 0       2610        7.4
# 1       1700        9.9
# 2       2000        7.6
# ...

# %%
from sklearn.model_selection import train_test_split
x_train,x_test,y_train,y_test=train_test_split(x,y,test_size=0.2,random_state=42)

# %%
x_test
# Out:
#      Sale  weight  resoloution  internal mem    ram  RearCam  Front_Cam  \
# 105   213    78.4         2.40           0.0  0.008      0.0        0.0
# 108   268   150.0         5.00          16.0  1.000     10.0        0.9
# 142  1530   152.0         5.20          16.0  3.000     20.7        2.2
# 55     45   174.0         5.50           4.0  0.512      5.0        0.0
# 94    164   134.0         4.50           8.0  0.512      5.0        0.0
# 29     26   118.0         5.00           8.0  1.000      8.0        2.0
# 101   201    78.4         2.40           0.0  0.008      0.0        0.0
# 51     43   260.0         7.00           4.0  0.512      2.0        0.0
# 100   198   158.0         5.10          16.0  2.000     16.0        2.0
# 143  1584   152.0         5.20          16.0  3.000     20.7        2.2
# 19     20   134.1         4.00           8.0  1.000      2.0        0.0
# 84    113   404.0         8.00           8.0  1.000      5.0        5.0
# ...

# %%
x_train
# Out:
#      Sale  weight  resoloution  internal mem  ram  RearCam  Front_Cam  \
# 115   309   174.0          5.7          32.0  4.0     16.0        5.0
# 2      10   110.0          4.7           8.0  1.5     13.0        5.0
# 123   399   194.8          5.7          16.0  2.0      8.0        1.0
# 45     40   131.0          5.0          16.0  2.0     13.0        5.0
# 42     38   133.5          4.5           8.0  1.0      5.0        0.0
# ..    ...     ...          ...           ...  ...      ...        ...
# 71     91   116.0          5.0          16.0  2.0     13.0        5.0
# 106   214   142.0          5.0          16.0  2.0     16.0        8.0
# 14     16   145.0          5.1          16.0  2.0     16.0        2.0
# 92    156   154.0          5.0           8.0  1.0     13.0        5.0
# 102   204   160.0          5.0           0.0  1.0      8.0        0.0
#
#      battery  thickness
# 115     3200        7.6
# 2       2000        7.6
# 123     3400       10.2
# 45      2500        8.7
# ...

# %%
y_train
# Out:
# 115    2858
# 2      1916
# 123    2001
# 45     1989
# 42     1843
#        ...
# 71     2276
# 106    2744
# 14     2580
# 92     1831
# 102    1522
# Name: Price, Length: 128, dtype: int64

# %%
y_test
# Out:
# 105     833
# 108    1676
# 142    2508
# 55     1777
# 94     1511
# 29     1950
# 101     833
# 51     1347
# 100    2343
# 143    2508
# 19     1238
# 84     1646
# 15     1612
# 66     2746
# 24     1942
# 30     2258
# 128    2491
# 148    3055
# 98     1522
# 16     2258
# 75     2276
# 18     1612
# 12     2174
# 9      2580
# 31     2977
# 152    4361
# 97     2562
# 56     3658
# 132    2466
# 104    2744
# 137    3116
# 78     2714
# 60     2824
# Name: Price, dtype: int64

# %%
from sklearn.linear_model import LinearRegression
model=LinearRegression()
model.fit(x_train,y_train)
# Out:
# LinearRegression()

# %%
y_pred=model.predict(x_test)
y_pred
# Out:
# array([ 988.10261793, 1929.91760012, 2745.81914781, 1581.9644361 ,
#        1595.60302665, 2078.94215308,  988.38695213, 1458.22475257,
#        2292.62288597, 2744.53964389, 1329.8876311 , 1654.26970228,
#        1791.87291989, 3035.79507515, 2107.86826793, 2055.94412335,
#        2421.70096004, 3320.81845096, 1632.84172848, 2056.157374  ,
#        2336.14897108, 1791.82553085, 2034.63128656, 2396.6459366 ,
#        2753.92892092, 4026.09864342, 2301.56204464, 3302.82450913,
#        2482.28793995, 2411.6001131 , 3034.77064676, 2500.98159166,
#        2727.95095036])

# %%
filename="lrmodel"
pickle.dump(model,open(filename,'wb'))

# %%
from sklearn.metrics import r2_score
r2_score(y_test,y_pred)
# Out:
# 0.9336922907208061

# %%
from sklearn.metrics import mean_squared_error
mean_squared_error(y_pred,y_test)
# Out:
# 37589.1130148975

# %%
results=pd.DataFrame(columns=['price','predicted'])
results['price']=y_test
results['predicted']=y_pred
results['ID']=results.index
results.head(15)
# Out:
#      price    predicted   ID
# 105    833   988.102618  105
# 108   1676  1929.917600  108
# 142   2508  2745.819148  142
# 55    1777  1581.964436   55
# 94    1511  1595.603027   94
# 29    1950  2078.942153   29
# 101    833   988.386952  101
# 51    1347  1458.224753   51
# 100   2343  2292.622886  100
# 143   2508  2744.539644  143
# 19    1238  1329.887631   19
# 84    1646  1654.269702   84
# 15    1612  1791.872920   15
# 66    2746  3035.795075   66
# 24    1942  2107.868268   24

# %%
import seaborn as sns
import matplotlib.pyplot as plt
sns.lineplot(x='ID',y='price',data=results.head(50))
sns.lineplot(x='ID',y='predicted',data=results.head(50))
# Out:
# <AxesSubplot:xlabel='ID', ylabel='price'>

# %%
cor_mat=data1.corr()

# %%
cor_mat
# Out:
#                  Price      Sale    weight  resoloution  internal mem  \
# Price         1.000000  0.273263  0.144555     0.404010      0.776738
# Sale          0.273263  1.000000  0.016114     0.017154      0.489308
# weight        0.144555  0.016114  1.000000     0.890416      0.098849
# resoloution   0.404010  0.017154  0.890416     1.000000      0.202660
# internal mem  0.776738  0.489308  0.098849     0.202660      1.000000
# ram           0.896915  0.373127  0.149283     0.327216      0.875354
# RearCam       0.739538  0.292164 -0.029448     0.249892      0.451917
# Front_Cam     0.675286  0.437233 -0.005971     0.202720      0.555733
# battery       0.559946  0.120338  0.833783     0.843462      0.461506
# thickness    -0.716773 -0.047991 -0.185262    -0.533708     -0.367412
#
#                    ram   RearCam  Front_Cam   battery  thickness
# Price         0.896915  0.739538   0.675286  0.559946  -0.716773
# Sale          0.373127  0.292164   0.437233  0.120338  -0.047991
# ...

# %%
sns.heatmap(cor_mat,vmax=1,vmin=-1,annot=True,linewidth=5)
# Out:
# <AxesSubplot:>
